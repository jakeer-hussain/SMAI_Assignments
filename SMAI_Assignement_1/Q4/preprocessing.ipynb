# %%
# import pandas as pd
# from sklearn.preprocessing import StandardScaler

# # Cleaning the data

# files = {
#     "train": "train_data.csv",
#     "test": "test_data.csv",
#     "val": "val_data.csv"
# }

# drop_columns = ["Address"]

# scaler = StandardScaler()
# for key, file in files.items():
#     df = pd.read_csv(file)

#     df.drop(columns=drop_columns, inplace=True, errors='ignore')

#     df.fillna(df.median(numeric_only=True), inplace=True)

#     numerical_features = df.select_dtypes(include=['number']).columns.tolist()
#     numerical_features.remove("FLAG")  # Don't scale FLAG

#     df[numerical_features] = scaler.fit_transform(df[numerical_features])

#     df.to_csv(f"{key}_cleaned.csv", index=False)
#     print(f"Saved: {key}_cleaned.csv")

# print("Preprocessing complete!")



# import pandas as pd

# # Load the cleaned datasets
# train_data = pd.read_csv('train_cleaned.csv')
# val_data = pd.read_csv('val_cleaned.csv')
# test_data = pd.read_csv('test_cleaned.csv')

# # Extract labels (first column) and save them to separate files
# train_labels = train_data.iloc[:, 0]
# val_labels = val_data.iloc[:, 0]
# test_labels = test_data.iloc[:, 0]

# train_labels.to_csv('train_label.csv', index=False, header=True)
# val_labels.to_csv('val_label.csv', index=False, header=True)
# test_labels.to_csv('test_label.csv', index=False, header=True)

# # Columns to remove
# columns_to_remove = ["avg val received", "total ether received"]

# # Remove the label column and the specified columns (keep only the required features)
# train_features = train_data.iloc[:, 1:].drop(columns=columns_to_remove, errors='ignore')
# val_features = val_data.iloc[:, 1:].drop(columns=columns_to_remove, errors='ignore')
# test_features = test_data.iloc[:, 1:].drop(columns=columns_to_remove, errors='ignore')

# # Save the updated cleaned data (only features)
# train_features.to_csv('train_features.csv', index=False, header=True)
# val_features.to_csv('val_features.csv', index=False, header=True)
# test_features.to_csv('test_features.csv', index=False, header=True)

# print("Labels extracted and saved as separate files. Features saved after column removal.")
